# %% [markdown]
# 1. Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %%
M = (200 + 800) / 2
M
# Out:
# 500.0

# %%
D = (800 - 200)**2 / 12
D
# Out:
# 30000.0

# %% [markdown]
# 2. О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %%
import numpy as np
l = np.sqrt(12 * 0.2) + 0.5
print('Левая граница', l)
m = (l - 0.5) / 2
print('Среднее', m)
# Out:
# Левая граница 2.049193338482967
# Среднее 0.7745966692414834

# %% [markdown]
# 3. Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-(x+2)**2) / 32).
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %%
M(X) = 2
D(X) = 4
std(X) = 2

# %% [markdown]
# 4. Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.

# %%
m = 174
std = 8
a = 182 - m
pa = 50 - 34
print('a) Отклонение равно', a, 'Вероятность', pa, '%')
b = 190 - m
pb = 50 - 95.4 / 2
print('б) Отклонение равно', b, 'Вероятность', pb, '%')
c = 166 - m
pc = 68 / 2 + 95.4 / 2
print('в) Отклонение равно от', c, 'до', b, 'Вероятность', pc, '%')
pd = 68
print('г) Отклонение равно от', c, 'до', a, 'Вероятность', pd, '%')
d = 158 - m
pc = 95.4
print('д) Отклонение равно от', d, 'до', b, 'Вероятность', pc, '%')
e = 150 - m
pe = 100 - (99.72 + 95.4) / 2
print('e) Отклонение равно до', e, 'от', b, 'Вероятность', pe, '%')
g = 198 - m
pg = 100 - 99.72
print('ё) Отклонение равно до', e, 'от', g, 'Вероятность', pg, '%')
pf = 50 - 68/2
print('ж) Отклонение равно от', c, 'Вероятность', pf, '%')
# Out:
# a) Отклонение равно 8 Вероятность 16 %
# б) Отклонение равно 16 Вероятность 2.299999999999997 %
# в) Отклонение равно от -8 до 16 Вероятность 81.7 %
# г) Отклонение равно от -8 до 8 Вероятность 68 %
# д) Отклонение равно от -16 до 16 Вероятность 95.4 %
# e) Отклонение равно до -24 от 16 Вероятность 2.4399999999999977 %
# ё) Отклонение равно до -24 от 24 Вероятность 0.28000000000000114 %
# ж) Отклонение равно от -8 Вероятность 16.0 %

# %% [markdown]
# 5. На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой
# M(X) = 178 см и D(X) = 25 кв.см?

# %%
n = (190 - 178) / 5
n
# Out:
# 2.4
